# %%
from scipy import io as sio
#import scipy as sio
import csv
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/Advertising.csv')
data
plt.plot(data['TV'])
plt.show()

# %%
import numpy as np
a=np.array([1,2,3])
a
# Out:
# array([1, 2, 3])

# %%
b=np.poly1d(a)
b
# Out:
# poly1d([1, 2, 3])

# %%
print(b)
# Out:
#    2
# 1 x + 2 x + 3

# %%
b.roots
# Out:
# array([-1.+1.41421356j, -1.-1.41421356j])

# %%
b.order
# Out:
# 2

# %%
d=np.array([2,3,4,5,6])
d
# Out:
# array([2, 3, 4, 5, 6])

# %%
d1=np.poly1d(d)
d1
# Out:
# poly1d([2, 3, 4, 5, 6])

# %%
print(d1)
# Out:
#    4     3     2
# 2 x + 3 x + 4 x + 5 x + 6

# %%
d1.order
# Out:
# 4

# %%
d1.roots
# Out:
# array([ 0.33691531+1.25867457j,  0.33691531-1.25867457j,
#        -1.08691531+0.76526803j, -1.08691531-0.76526803j])

# %%
x=np.array([1,2,3])
y=np.array([3,2,1])

# %%
a=np.polyadd(x,y)
print(a)
# Out:
# [4 4 4]

# %%
a1=np.polysub(x,y)
print(a1)
# Out:
# [-2  0  2]

# %%
a2=np.polymul(x,y)
print(a2)
# Out:
# [ 3  8 14  8  3]

# %%
a3=np.polydiv(x,y)
print(a3)
# Out:
# (array([0.33333333]), array([1.33333333, 2.66666667]))

# %%
a4=np.polyfit(x,y,2)
print(a4)
# Out:
# [ 7.59820606e-16 -1.00000000e+00  4.00000000e+00]

# %%
np.polyval(x,y)
# Out:
# array([18, 11,  6])

# %%
z=[4,5,6]

# %% [markdown]
# $4*x^2+5*x+6$

# %%
np.polyval(z,2)
# Out:
# 32

# %%
np.polyval([4,5,6],3)
# Out:
# 57

# %%
x=[2,4,6]
y=[8,10,12]

# %%
np.polyval(x,y)
# Out:
# array([166, 246, 342])

# %%
np.polyval(x,2)
# Out:
# 22

# %%
np.polyval(y,2)
# Out:
# 64

# %%
np.corrcoef(x,y) #correlation coefficients
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
np.cov(x,y)#covariance
# Out:
# array([[4., 4.],
#        [4., 4.]])

# %%
np.all([True,False,False])# if all the values true in the  list true other wise false
# Out:
# False

# %%
np.all([True,True,True])
# Out:
# True

# %%
np.any([True,False,True])#if any one is true in the list the value true
# Out:
# True

# %%
m=np.random.random(10)
m
# Out:
# array([0.10124722, 0.45066942, 0.28241005, 0.73446806, 0.99996158,
#        0.34825856, 0.99476653, 0.94758854, 0.56949901, 0.97114214])

# %%
np.argmin(m)# it shows the indexing position
# Out:
# 0

# %%
np.min(m) #it shows the indexing value
# Out:
# 0.101247217796817

# %%
np.argmax(m)
# Out:
# 4

# %%
np.max(m)
# Out:
# 0.9999615791850466

# %%
np.argsort(m)# it sorting the min to max elements in the list
# Out:
# array([0, 2, 5, 1, 8, 3, 7, 9, 6, 4])

# %%
m1=np.array([[1,2],[3,4]])
np.argmax(m1,axis=1)
# Out:
# array([1, 1])

# %%
m=np.array([10,2.5,3.5,np.nan])
m
# Out:
# array([10. ,  2.5,  3.5,  nan])

# %%
m+10 # it adding to the list  above  in each element
# Out:
# array([20. , 12.5, 13.5,  nan])

# %%
np.nan+2
# Out:
# nan

# %%
np.inf*2
# Out:
# inf

# %%
m.dtype
# Out:
# dtype('float64')

# %%
np.nan_to_num(m)
# Out:
# array([10. ,  2.5,  3.5,  0. ])

# %%
np.nanmin(m)
# Out:
# 2.5

# %%
np.nanmax(m)
# Out:
# 10.0

# %%
np.average(m)
# Out:
# nan

# %%
x
# Out:
# [2, 4, 6]

# %%
np.average(x)
# Out:
# 4.0

# %%
np.mean(x)
# Out:
# 4.0

# %%
np.median(x)
# Out:
# 4.0

# %%
np.std(x)#standerd deviation
# Out:
# 1.632993161855452

# %%
np.bincount(x)
# Out:
# array([0, 0, 1, 0, 1, 0, 1])

# %%
b=np.array([0,1,2,4])
np.bincount(b)
# Out:
# array([1, 1, 1, 0, 1])

# %%
c=np.array([-1.7,-1.5,-0.2,0.2,1.5,1.7])
c
# Out:
# array([-1.7, -1.5, -0.2,  0.2,  1.5,  1.7])

# %%
np.ceil(c)
# Out:
# array([-1., -1., -0.,  1.,  2.,  2.])

# %%
np.clip(np.arange(10),2,8)# it take the values in 2 before vale 2 and 8 after value 8 in between the range
# Out:
# array([2, 2, 2, 3, 4, 5, 6, 7, 8, 8])

# %%
np.conjugate(1-2j)# conjugate menas opposite of the given input
# Out:
# (1+2j)

# %%
np.cross(x,y)
print(x)
print(y)
# Out:
# [2, 4, 6]
# [8, 10, 12]

# %%
x
# Out:
# [2, 4, 6]

# %%
y
# Out:
# [8, 10, 12]

# %% [markdown]
# $(u_1,u_2,u_3)*(v_1,v_2,v_3)=(u_2v_3-u_3v_2,u_2v_1-u_1v_3,u_1v_2-u_2v_1)$

# %%
d=np.array([1,2,3])#cumulative product 
np.cumprod(d)
# Out:
# array([1, 2, 6])

# %%
np.cumsum(d)#cumulative sum
# Out:
# array([1, 3, 6])
